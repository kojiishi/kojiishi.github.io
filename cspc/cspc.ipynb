# %% [markdown]
# ### Preparations and Unicode data

# %%
# !python -V
import numpy as np
import pandas as pd
import unicodedata
# Out:
# Python 3.6.7

# %%
def u_hex(c):
  return ('00000' + hex(ord(c))[2:].upper())[-6:]

def u_name_or_null(c):
  try:
    return unicodedata.name(c)
  except ValueError:
    return None

def get_unicode_list(range):
  return [[
    u_hex(c),
    c,
    u_name_or_null(c),
    unicodedata.category(c),
    unicodedata.east_asian_width(c),
  ] for c in [chr(c) for c in range]]

def get_unicode_df(range):
  return pd.DataFrame(get_unicode_list(range),
                      index=range,
                      columns=['hex', 'char', 'name', 'gc', 'eaw'])

r = range(0x20, 0x1FFFF)
u = get_unicode_df(r)
u.head(11)
# Out:
#        hex char               name  gc eaw
# 32  000020                   SPACE  Zs  Na
# 33  000021    !   EXCLAMATION MARK  Po  Na
# 34  000022    "     QUOTATION MARK  Po  Na
# 35  000023    #        NUMBER SIGN  Po  Na
# 36  000024    $        DOLLAR SIGN  Sc  Na
# 37  000025    %       PERCENT SIGN  Po  Na
# 38  000026    &          AMPERSAND  Po  Na
# 39  000027    '         APOSTROPHE  Po  Na
# 40  000028    (   LEFT PARENTHESIS  Ps  Na
# 41  000029    )  RIGHT PARENTHESIS  Pe  Na
# 42  00002A    *           ASTERISK  Po  Na

# %% [markdown]
# ### Add [original feature file](http://blogs.adobe.com/CCJKType/files/2018/04/features.txt) from [Ken's CJK Type blog](https://blogs.adobe.com/CCJKType/2018/04/contextual-spacing.html)

# %%
d = {
  'open': [0x2018, 0x201C, 0x3008, 0x300A, 0x300C, 0x300E, 0x3010, 0x3014, 0x3016, 0x3018, 0x301A, 0x301D, 0xFF08, 0xFF3B, 0xFF5B, 0xFF5F],
  'close': [0x2019, 0x201D, 0x3009, 0x300B, 0x300D, 0x300F, 0x3011, 0x3015, 0x3017, 0x3019, 0x301B, 0x301F, 0xFF09, 0xFF3D, 0xFF5D, 0xFF60],
  'PeriodComma': [0x3001, 0x3002, 0xFF0C, 0xFF0E],
  'ColonExclamQuestion': [0xFF01, 0xFF1F],
  'ColonExclamQuestion.cn': [0xFF01, 0xFF1A, 0xFF1B, 0xFF1F],
  'center': [0x30FB, 0xFF1A, 0xFF1B],
  'center.tw': [0x3001, 0x3002, 0xFF0C, 0xFF0E],
  'vopen': [0x2018, 0x201C, 0x3018, 0x301A, 0xFE17, 0xFE35, 0xFE37, 0xFE39, 0xFE3B, 0xFE3D, 0xFE3F, 0xFE41, 0xFE43, 0xFE47, 0xFF5F],
  'vclose': [0x2019, 0x201D, 0x3019, 0x301B, 0xFE18, 0xFE36, 0xFE38, 0xFE3A, 0xFE3C, 0xFE3E, 0xFE40, 0xFE42, 0xFE44, 0xFE48, 0xFE60],
  'vPeriodComma': [0xFE10, 0xFE11, 0xFE12, 0xFF0E],
  'vColonExclamQuestion': [0xFE13, 0xFE14, 0xFE15, 0xFE16, 0xFF01, 0xFF1A, 0xFF1B, 0xFF1F],
  'vcenter': [0x30FB, 0xFF1A],
  'vcenter.tw': [0x3001, 0x3002, 0xFF0C, 0xFF0E],
}
s = None
for value, list in d.items():
  s1 = pd.Series(value, index=list)
  if s is None:
    s = s1
  else:
    s = s.combine(s1, lambda x, y: x if pd.isnull(y) else (y if pd.isnull(x) else str(x)+', '+str(y)))
u = u.assign(cspc=s)
u.query('cspc > ""').head(10)
# Out:
#           hex char                         name  gc eaw  \
# 8216   002018    ‘   LEFT SINGLE QUOTATION MARK  Pi   A
# 8217   002019    ’  RIGHT SINGLE QUOTATION MARK  Pf   A
# 8220   00201C    “   LEFT DOUBLE QUOTATION MARK  Pi   A
# 8221   00201D    ”  RIGHT DOUBLE QUOTATION MARK  Pf   A
# 12289  003001    、            IDEOGRAPHIC COMMA  Po   W
# 12290  003002    。        IDEOGRAPHIC FULL STOP  Po   W
# 12296  003008    〈           LEFT ANGLE BRACKET  Ps   W
# 12297  003009    〉          RIGHT ANGLE BRACKET  Pe   W
# 12298  00300A    《    LEFT DOUBLE ANGLE BRACKET  Ps   W
# 12299  00300B    》   RIGHT DOUBLE ANGLE BRACKET  Pe   W
#
#                                      cspc
# 8216                          open, vopen
# 8217                        close, vclose
# 8220                          open, vopen
# 8221                        close, vclose
# 12289  PeriodComma, center.tw, vcenter.tw
# 12290  PeriodComma, center.tw, vcenter.tw
# 12296                                open
# 12297                               close
# 12298                                open
# 12299                               close

# %% [markdown]
# ### [CSS Text 4 Character classes](https://drafts.csswg.org/css-text-4/#text-spacing-classes)

# %%
s = pd.Series(dtype=object)
for c in r:
  v = []
  gc = unicodedata.category(chr(c))
  eaw = unicodedata.east_asian_width(chr(c))
  if (gc == 'Ps' and ((c >= 0x3000 and c <=0x303F) or eaw == 'F')) or c in [0x2018, 0x201C]:
    v.append('open')
  if (gc == 'Pe' and ((c >= 0x3000 and c <=0x303F) or eaw == 'F')) or c in [0x2019, 0x201D]:
    v.append('close')
  if c in [0x00B7, 0x2027, 0x30FB]:
    v.append('middle')
  if c in [0xFF1A, 0xFF1B]:
    v.append('colon')
  if c in [0x3001, 0x3002, 0xFF0C, 0xFF0E]:
    v.append('dot')
  if v:
    s.at[c] = ', '.join(v)
u = u.assign(css4=s)
u.query('css4 > ""').head(10)
# Out:
#           hex char                         name  gc eaw  \
# 183    0000B7    ·                   MIDDLE DOT  Po   A
# 8216   002018    ‘   LEFT SINGLE QUOTATION MARK  Pi   A
# 8217   002019    ’  RIGHT SINGLE QUOTATION MARK  Pf   A
# 8220   00201C    “   LEFT DOUBLE QUOTATION MARK  Pi   A
# 8221   00201D    ”  RIGHT DOUBLE QUOTATION MARK  Pf   A
# 8231   002027    ‧            HYPHENATION POINT  Po   A
# 12289  003001    、            IDEOGRAPHIC COMMA  Po   W
# 12290  003002    。        IDEOGRAPHIC FULL STOP  Po   W
# 12296  003008    〈           LEFT ANGLE BRACKET  Ps   W
# 12297  003009    〉          RIGHT ANGLE BRACKET  Pe   W
#
#                                      cspc    css4
# 183                                   NaN  middle
# 8216                          open, vopen    open
# 8217                        close, vclose   close
# 8220                          open, vopen    open
# 8221                        close, vclose   close
# 8231                                  NaN  middle
# 12289  PeriodComma, center.tw, vcenter.tw     dot
# 12290  PeriodComma, center.tw, vcenter.tw     dot
# 12296                                open    open
# 12297                               close   close

# %% [markdown]
# ### Comparisons

# %%
# Either CSPC or CSS4 is set
pd.options.display.max_rows = None
u.query('cspc == cspc or css4 == css4')
# Out:
#           hex char                                               name  gc eaw  \
# 183    0000B7    ·                                         MIDDLE DOT  Po   A
# 8216   002018    ‘                         LEFT SINGLE QUOTATION MARK  Pi   A
# 8217   002019    ’                        RIGHT SINGLE QUOTATION MARK  Pf   A
# 8220   00201C    “                         LEFT DOUBLE QUOTATION MARK  Pi   A
# 8221   00201D    ”                        RIGHT DOUBLE QUOTATION MARK  Pf   A
# 8231   002027    ‧                                  HYPHENATION POINT  Po   A
# 12289  003001    、                                  IDEOGRAPHIC COMMA  Po   W
# 12290  003002    。                              IDEOGRAPHIC FULL STOP  Po   W
# 12296  003008    〈                                 LEFT ANGLE BRACKET  Ps   W
# 12297  003009    〉                                RIGHT ANGLE BRACKET  Pe   W
# 12298  00300A    《                          LEFT DOUBLE ANGLE BRACKET  Ps   W
# 12299  00300B    》                         RIGHT DOUBLE ANGLE BRACKET  Pe   W
# 12300  00300C    「                                LEFT CORNER BRACKET  Ps   W
# 12301  00300D    」                               RIGHT CORNER BRACKET  Pe   W
# 12302  00300E    『                          LEFT WHITE CORNER BRACKET  Ps   W
# 12303  00300F    』                         RIGHT WHITE CORNER BRACKET  Pe   W
# 12304  003010    【                      LEFT BLACK LENTICULAR BRACKET  Ps   W
# 12305  003011    】                     RIGHT BLACK LENTICULAR BRACKET  Pe   W
# 12308  003014    〔                        LEFT TORTOISE SHELL BRACKET  Ps   W
# 12309  003015    〕                       RIGHT TORTOISE SHELL BRACKET  Pe   W
# 12310  003016    〖                      LEFT WHITE LENTICULAR BRACKET  Ps   W
# 12311  003017    〗                     RIGHT WHITE LENTICULAR BRACKET  Pe   W
# 12312  003018    〘                  LEFT WHITE TORTOISE SHELL BRACKET  Ps   W
# 12313  003019    〙                 RIGHT WHITE TORTOISE SHELL BRACKET  Pe   W
# 12314  00301A    〚                          LEFT WHITE SQUARE BRACKET  Ps   W
# 12315  00301B    〛                         RIGHT WHITE SQUARE BRACKET  Pe   W
# 12317  00301D    〝               REVERSED DOUBLE PRIME QUOTATION MARK  Ps   W
# 12318  00301E    〞                        DOUBLE PRIME QUOTATION MARK  Pe   W
# 12319  00301F    〟                    LOW DOUBLE PRIME QUOTATION MARK  Pe   W
# 12539  0030FB    ・                                KATAKANA MIDDLE DOT  Po   W
# 65040  00FE10    ︐               PRESENTATION FORM FOR VERTICAL COMMA  Po   W
# 65041  00FE11    ︑   PRESENTATION FORM FOR VERTICAL IDEOGRAPHIC COMMA  Po   W
# 65042  00FE12    ︒  PRESENTATION FORM FOR VERTICAL IDEOGRAPHIC FUL...  Po   W
# 65043  00FE13    ︓               PRESENTATION FORM FOR VERTICAL COLON  Po   W
# 65044  00FE14    ︔           PRESENTATION FORM FOR VERTICAL SEMICOLON  Po   W
# 65045  00FE15    ︕    PRESENTATION FORM FOR VERTICAL EXCLAMATION MARK  Po   W
# 65046  00FE16    ︖       PRESENTATION FORM FOR VERTICAL QUESTION MARK  Po   W
# 65047  00FE17    ︗  PRESENTATION FORM FOR VERTICAL LEFT WHITE LENT...  Ps   W
# 65048  00FE18    ︘  PRESENTATION FORM FOR VERTICAL RIGHT WHITE LEN...  Pe   W
# 65077  00FE35    ︵    PRESENTATION FORM FOR VERTICAL LEFT PARENTHESIS  Ps   W
# 65078  00FE36    ︶   PRESENTATION FORM FOR VERTICAL RIGHT PARENTHESIS  Pe   W
# 65079  00FE37    ︷  PRESENTATION FORM FOR VERTICAL LEFT CURLY BRACKET  Ps   W
# 65080  00FE38    ︸  PRESENTATION FORM FOR VERTICAL RIGHT CURLY BRA...  Pe   W
# 65081  00FE39    ︹  PRESENTATION FORM FOR VERTICAL LEFT TORTOISE S...  Ps   W
# 65082  00FE3A    ︺  PRESENTATION FORM FOR VERTICAL RIGHT TORTOISE ...  Pe   W
# 65083  00FE3B    ︻  PRESENTATION FORM FOR VERTICAL LEFT BLACK LENT...  Ps   W
# 65084  00FE3C    ︼  PRESENTATION FORM FOR VERTICAL RIGHT BLACK LEN...  Pe   W
# 65085  00FE3D    ︽  PRESENTATION FORM FOR VERTICAL LEFT DOUBLE ANG...  Ps   W
# 65086  00FE3E    ︾  PRESENTATION FORM FOR VERTICAL RIGHT DOUBLE AN...  Pe   W
# 65087  00FE3F    ︿  PRESENTATION FORM FOR VERTICAL LEFT ANGLE BRACKET  Ps   W
# 65088  00FE40    ﹀  PRESENTATION FORM FOR VERTICAL RIGHT ANGLE BRA...  Pe   W
# 65089  00FE41    ﹁  PRESENTATION FORM FOR VERTICAL LEFT CORNER BRA...  Ps   W
# 65090  00FE42    ﹂  PRESENTATION FORM FOR VERTICAL RIGHT CORNER BR...  Pe   W
# 65091  00FE43    ﹃  PRESENTATION FORM FOR VERTICAL LEFT WHITE CORN...  Ps   W
# 65092  00FE44    ﹄  PRESENTATION FORM FOR VERTICAL RIGHT WHITE COR...  Pe   W
# 65095  00FE47    ﹇  PRESENTATION FORM FOR VERTICAL LEFT SQUARE BRA...  Ps   W
# 65096  00FE48    ﹈  PRESENTATION FORM FOR VERTICAL RIGHT SQUARE BR...  Pe   W
# 65120  00FE60    ﹠                                    SMALL AMPERSAND  Po   W
# 65281  00FF01    ！                         FULLWIDTH EXCLAMATION MARK  Po   F
# 65288  00FF08    （                         FULLWIDTH LEFT PARENTHESIS  Ps   F
# 65289  00FF09    ）                        FULLWIDTH RIGHT PARENTHESIS  Pe   F
# 65292  00FF0C    ，                                    FULLWIDTH COMMA  Po   F
# 65294  00FF0E    ．                                FULLWIDTH FULL STOP  Po   F
# 65306  00FF1A    ：                                    FULLWIDTH COLON  Po   F
# 65307  00FF1B    ；                                FULLWIDTH SEMICOLON  Po   F
# 65311  00FF1F    ？                            FULLWIDTH QUESTION MARK  Po   F
# 65339  00FF3B    ［                      FULLWIDTH LEFT SQUARE BRACKET  Ps   F
# 65341  00FF3D    ］                     FULLWIDTH RIGHT SQUARE BRACKET  Pe   F
# 65371  00FF5B    ｛                       FULLWIDTH LEFT CURLY BRACKET  Ps   F
# 65373  00FF5D    ｝                      FULLWIDTH RIGHT CURLY BRACKET  Pe   F
# 65375  00FF5F    ｟                   FULLWIDTH LEFT WHITE PARENTHESIS  Ps   F
# 65376  00FF60    ｠                  FULLWIDTH RIGHT WHITE PARENTHESIS  Pe   F
#
#                                                     cspc    css4
# 183                                                  NaN  middle
# 8216                                         open, vopen    open
# 8217                                       close, vclose   close
# 8220                                         open, vopen    open
# 8221                                       close, vclose   close
# 8231                                                 NaN  middle
# 12289                 PeriodComma, center.tw, vcenter.tw     dot
# 12290                 PeriodComma, center.tw, vcenter.tw     dot
# 12296                                               open    open
# 12297                                              close   close
# 12298                                               open    open
# 12299                                              close   close
# 12300                                               open    open
# 12301                                              close   close
# 12302                                               open    open
# 12303                                              close   close
# 12304                                               open    open
# 12305                                              close   close
# 12308                                               open    open
# 12309                                              close   close
# 12310                                               open    open
# 12311                                              close   close
# 12312                                        open, vopen    open
# 12313                                      close, vclose   close
# 12314                                        open, vopen    open
# 12315                                      close, vclose   close
# 12317                                               open    open
# 12318                                                NaN   close
# 12319                                              close   close
# 12539                                    center, vcenter  middle
# 65040                                       vPeriodComma     NaN
# 65041                                       vPeriodComma     NaN
# 65042                                       vPeriodComma     NaN
# 65043                               vColonExclamQuestion     NaN
# 65044                               vColonExclamQuestion     NaN
# 65045                               vColonExclamQuestion     NaN
# 65046                               vColonExclamQuestion     NaN
# 65047                                              vopen     NaN
# 65048                                             vclose     NaN
# 65077                                              vopen     NaN
# 65078                                             vclose     NaN
# 65079                                              vopen     NaN
# 65080                                             vclose     NaN
# 65081                                              vopen     NaN
# 65082                                             vclose     NaN
# 65083                                              vopen     NaN
# 65084                                             vclose     NaN
# 65085                                              vopen     NaN
# 65086                                             vclose     NaN
# 65087                                              vopen     NaN
# 65088                                             vclose     NaN
# 65089                                              vopen     NaN
# 65090                                             vclose     NaN
# 65091                                              vopen     NaN
# 65092                                             vclose     NaN
# 65095                                              vopen     NaN
# 65096                                             vclose     NaN
# 65120                                             vclose     NaN
# 65281  ColonExclamQuestion, ColonExclamQuestion.cn, v...     NaN
# 65288                                               open    open
# 65289                                              close   close
# 65292                 PeriodComma, center.tw, vcenter.tw     dot
# 65294   PeriodComma, center.tw, vPeriodComma, vcenter.tw     dot
# 65306  ColonExclamQuestion.cn, center, vColonExclamQu...   colon
# 65307  ColonExclamQuestion.cn, center, vColonExclamQu...   colon
# 65311  ColonExclamQuestion, ColonExclamQuestion.cn, v...     NaN
# 65339                                               open    open
# 65341                                              close   close
# 65371                                               open    open
# 65373                                              close   close
# 65375                                        open, vopen    open
# 65376                                              close   close

# %%
# CSPC is not set but CSS4 is set
u.query('cspc != cspc and css4 == css4')
# Out:
#           hex char                         name  gc eaw cspc    css4
# 183    0000B7    ·                   MIDDLE DOT  Po   A  NaN  middle
# 8231   002027    ‧            HYPHENATION POINT  Po   A  NaN  middle
# 12318  00301E    〞  DOUBLE PRIME QUOTATION MARK  Pe   W  NaN   close

# %%
# CSPC is set but CSS4 is not set
u.query('cspc == cspc and css4 != css4')
# Out:
#           hex char                                               name  gc eaw  \
# 65040  00FE10    ︐               PRESENTATION FORM FOR VERTICAL COMMA  Po   W
# 65041  00FE11    ︑   PRESENTATION FORM FOR VERTICAL IDEOGRAPHIC COMMA  Po   W
# 65042  00FE12    ︒  PRESENTATION FORM FOR VERTICAL IDEOGRAPHIC FUL...  Po   W
# 65043  00FE13    ︓               PRESENTATION FORM FOR VERTICAL COLON  Po   W
# 65044  00FE14    ︔           PRESENTATION FORM FOR VERTICAL SEMICOLON  Po   W
# 65045  00FE15    ︕    PRESENTATION FORM FOR VERTICAL EXCLAMATION MARK  Po   W
# 65046  00FE16    ︖       PRESENTATION FORM FOR VERTICAL QUESTION MARK  Po   W
# 65047  00FE17    ︗  PRESENTATION FORM FOR VERTICAL LEFT WHITE LENT...  Ps   W
# 65048  00FE18    ︘  PRESENTATION FORM FOR VERTICAL RIGHT WHITE LEN...  Pe   W
# 65077  00FE35    ︵    PRESENTATION FORM FOR VERTICAL LEFT PARENTHESIS  Ps   W
# 65078  00FE36    ︶   PRESENTATION FORM FOR VERTICAL RIGHT PARENTHESIS  Pe   W
# 65079  00FE37    ︷  PRESENTATION FORM FOR VERTICAL LEFT CURLY BRACKET  Ps   W
# 65080  00FE38    ︸  PRESENTATION FORM FOR VERTICAL RIGHT CURLY BRA...  Pe   W
# 65081  00FE39    ︹  PRESENTATION FORM FOR VERTICAL LEFT TORTOISE S...  Ps   W
# 65082  00FE3A    ︺  PRESENTATION FORM FOR VERTICAL RIGHT TORTOISE ...  Pe   W
# 65083  00FE3B    ︻  PRESENTATION FORM FOR VERTICAL LEFT BLACK LENT...  Ps   W
# 65084  00FE3C    ︼  PRESENTATION FORM FOR VERTICAL RIGHT BLACK LEN...  Pe   W
# 65085  00FE3D    ︽  PRESENTATION FORM FOR VERTICAL LEFT DOUBLE ANG...  Ps   W
# 65086  00FE3E    ︾  PRESENTATION FORM FOR VERTICAL RIGHT DOUBLE AN...  Pe   W
# 65087  00FE3F    ︿  PRESENTATION FORM FOR VERTICAL LEFT ANGLE BRACKET  Ps   W
# 65088  00FE40    ﹀  PRESENTATION FORM FOR VERTICAL RIGHT ANGLE BRA...  Pe   W
# 65089  00FE41    ﹁  PRESENTATION FORM FOR VERTICAL LEFT CORNER BRA...  Ps   W
# 65090  00FE42    ﹂  PRESENTATION FORM FOR VERTICAL RIGHT CORNER BR...  Pe   W
# 65091  00FE43    ﹃  PRESENTATION FORM FOR VERTICAL LEFT WHITE CORN...  Ps   W
# 65092  00FE44    ﹄  PRESENTATION FORM FOR VERTICAL RIGHT WHITE COR...  Pe   W
# 65095  00FE47    ﹇  PRESENTATION FORM FOR VERTICAL LEFT SQUARE BRA...  Ps   W
# 65096  00FE48    ﹈  PRESENTATION FORM FOR VERTICAL RIGHT SQUARE BR...  Pe   W
# 65120  00FE60    ﹠                                    SMALL AMPERSAND  Po   W
# 65281  00FF01    ！                         FULLWIDTH EXCLAMATION MARK  Po   F
# 65311  00FF1F    ？                            FULLWIDTH QUESTION MARK  Po   F
#
#                                                     cspc css4
# 65040                                       vPeriodComma  NaN
# 65041                                       vPeriodComma  NaN
# 65042                                       vPeriodComma  NaN
# 65043                               vColonExclamQuestion  NaN
# 65044                               vColonExclamQuestion  NaN
# 65045                               vColonExclamQuestion  NaN
# 65046                               vColonExclamQuestion  NaN
# 65047                                              vopen  NaN
# 65048                                             vclose  NaN
# 65077                                              vopen  NaN
# 65078                                             vclose  NaN
# 65079                                              vopen  NaN
# 65080                                             vclose  NaN
# 65081                                              vopen  NaN
# 65082                                             vclose  NaN
# 65083                                              vopen  NaN
# 65084                                             vclose  NaN
# 65085                                              vopen  NaN
# 65086                                             vclose  NaN
# 65087                                              vopen  NaN
# 65088                                             vclose  NaN
# 65089                                              vopen  NaN
# 65090                                             vclose  NaN
# 65091                                              vopen  NaN
# 65092                                             vclose  NaN
# 65095                                              vopen  NaN
# 65096                                             vclose  NaN
# 65120                                             vclose  NaN
# 65281  ColonExclamQuestion, ColonExclamQuestion.cn, v...  NaN
# 65311  ColonExclamQuestion, ColonExclamQuestion.cn, v...  NaN

# %%
# Differences where both are set
u.query('cspc == cspc and css4 == css4 and cspc != css4')
# Out:
#           hex char                                name  gc eaw  \
# 8216   002018    ‘          LEFT SINGLE QUOTATION MARK  Pi   A
# 8217   002019    ’         RIGHT SINGLE QUOTATION MARK  Pf   A
# 8220   00201C    “          LEFT DOUBLE QUOTATION MARK  Pi   A
# 8221   00201D    ”         RIGHT DOUBLE QUOTATION MARK  Pf   A
# 12289  003001    、                   IDEOGRAPHIC COMMA  Po   W
# 12290  003002    。               IDEOGRAPHIC FULL STOP  Po   W
# 12312  003018    〘   LEFT WHITE TORTOISE SHELL BRACKET  Ps   W
# 12313  003019    〙  RIGHT WHITE TORTOISE SHELL BRACKET  Pe   W
# 12314  00301A    〚           LEFT WHITE SQUARE BRACKET  Ps   W
# 12315  00301B    〛          RIGHT WHITE SQUARE BRACKET  Pe   W
# 12539  0030FB    ・                 KATAKANA MIDDLE DOT  Po   W
# 65292  00FF0C    ，                     FULLWIDTH COMMA  Po   F
# 65294  00FF0E    ．                 FULLWIDTH FULL STOP  Po   F
# 65306  00FF1A    ：                     FULLWIDTH COLON  Po   F
# 65307  00FF1B    ；                 FULLWIDTH SEMICOLON  Po   F
# 65375  00FF5F    ｟    FULLWIDTH LEFT WHITE PARENTHESIS  Ps   F
#
#                                                     cspc    css4
# 8216                                         open, vopen    open
# 8217                                       close, vclose   close
# 8220                                         open, vopen    open
# 8221                                       close, vclose   close
# 12289                 PeriodComma, center.tw, vcenter.tw     dot
# 12290                 PeriodComma, center.tw, vcenter.tw     dot
# 12312                                        open, vopen    open
# 12313                                      close, vclose   close
# 12314                                        open, vopen    open
# 12315                                      close, vclose   close
# 12539                                    center, vcenter  middle
# 65292                 PeriodComma, center.tw, vcenter.tw     dot
# 65294   PeriodComma, center.tw, vPeriodComma, vcenter.tw     dot
# 65306  ColonExclamQuestion.cn, center, vColonExclamQu...   colon
# 65307  ColonExclamQuestion.cn, center, vColonExclamQu...   colon
# 65375                                        open, vopen    open
